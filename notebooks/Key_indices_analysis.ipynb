# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# %%
df_all = pd.read_csv('Prices_since_2009_merged_Brent_Coal_Vol_LNG.csv')
df_all['Date'] = pd.to_datetime(df_all['Date'])
df_all.head()
# Out:
#         Date Brent_Vol.  Brent_Price  CBOE_Vol.  CBOE_Price Coal_Vol.  \
# 0 2009-01-01        NaN          NaN        NaN         NaN       NaN
# 1 2009-01-02     85.07K        46.91        NaN       39.19       NaN
# 2 2009-01-05    109.47K        49.62        NaN       39.08       NaN
# 3 2009-01-06    119.83K        50.53        NaN       38.56       NaN
# 4 2009-01-07    130.44K        45.86        NaN       43.39       NaN
#
#    Coal_Price  HenryHub_Price JKM_Vol.  JKM_Price  NBP_Price  PSV_Price  \
# 0         NaN             NaN      NaN        NaN        NaN        NaN
# 1       74.35            5.41      NaN        NaN        NaN        NaN
# 2       77.65            5.83      NaN        NaN        NaN        NaN
# 3       81.25            6.10      NaN        NaN        NaN        NaN
# 4       78.65            5.89      NaN        NaN        NaN        NaN
#
#    TTF_Price
# 0      21.00
# 1      22.20
# 2      22.85
# 3      26.00
# 4      26.33

# %%
# Columns to plot
cols_to_plot = [
    'Brent_Price', 'CBOE_Price', 'Coal_Price', 'HenryHub_Price',
    'JKM_Price', 'NBP_Price', 'PSV_Price', 'TTF_Price'
]

# Ensure numeric types
for col in cols_to_plot:
    df_all[col] = pd.to_numeric(df_all[col], errors='coerce')

# Create the figure
fig = go.Figure()
for col in cols_to_plot:
    fig.add_trace(go.Scatter(x=df_all['Date'], y=df_all[col], mode='lines', name=col))

# Update layout
fig.update_layout(
    title='Energy Market Price Trends Over Time',
    xaxis_title='Date',
    yaxis_title='Price (various units)',
    xaxis=dict(
        tickformat='%Y-%m',
        tickangle=45,
        dtick="M3",
        tickfont=dict(size=8)  # 👈 Adjust x-axis tick label size here
    ),
    yaxis=dict(
        tickfont=dict(size=8)  # 👈 Adjust y-axis tick label size here
    ),
    hovermode='x unified',
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Columns to plot
cols_to_plot = ['Brent_Price', 'CBOE_Price', 'Coal_Price', 'HenryHub_Price',
    'JKM_Price', 'NBP_Price', 'PSV_Price', 'TTF_Price'
]

scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_all[cols_to_plot]), columns=cols_to_plot)
df_scaled['Date'] = df_all['Date']

fig = go.Figure()
for col in cols_to_plot:
    fig.add_trace(go.Scatter(x=df_scaled['Date'], y=df_scaled[col], mode='lines', name=col))

fig.update_layout(
    title='Normalized Energy Price Trends (Scaled)',
    xaxis_title='Date',
    yaxis_title='Scaled Value',
    xaxis=dict(tickformat='%Y-%m', tickangle=-45, dtick="M3", tickfont=dict(size=8)),
    yaxis=dict(tickfont=dict(size=10)),
    hovermode='x unified',
    height=600
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Summary Timeline (Pre-War LNG Price Surge)
# | Period              | Key Events                                  | LNG Market Response              |
# | ------------------- | ------------------------------------------- | -------------------------------- |
# | Sep–Nov 2021        | Low European gas storage, early winter      | LNG prices begin to rise sharply |
# | Dec 2021 – Jan 2022 | Russia–Ukraine tensions escalate, cold snap | JKM hits historical highs        |
# | Feb 2022 (pre-24th) | Full-scale invasion anticipated             | Panic buying, market volatility  |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
from tensorflow.keras import Input, Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import joblib
import plotly.io as pio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/BKW/LNG Project data/' # if running this notebook in colab
# data_path = '../../data/LNG Project data/' # if running this notebook locally

# %%
file_path = 'clean_data/Prices_since_2009_merged_Brent_Coal_Vol_LNG.csv'

# %%
# Load and prepare data
df_all = pd.read_csv(data_path + file_path)
df_all['Date'] = pd.to_datetime(df_all['Date'])
df_all.head()
# Out:
#         Date Brent_Vol.  Brent_Price  CBOE_Vol.  CBOE_Price Coal_Vol.  \
# 0 2009-01-01        NaN          NaN        NaN         NaN       NaN
# 1 2009-01-02     85.07K        46.91        NaN       39.19       NaN
# 2 2009-01-05    109.47K        49.62        NaN       39.08       NaN
# 3 2009-01-06    119.83K        50.53        NaN       38.56       NaN
# 4 2009-01-07    130.44K        45.86        NaN       43.39       NaN
#
#    Coal_Price  HenryHub_Price JKM_Vol.  JKM_Price  NBP_Price  PSV_Price  \
# 0         NaN             NaN      NaN        NaN        NaN        NaN
# 1       74.35            5.41      NaN        NaN        NaN        NaN
# 2       77.65            5.83      NaN        NaN        NaN        NaN
# 3       81.25            6.10      NaN        NaN        NaN        NaN
# 4       78.65            5.89      NaN        NaN        NaN        NaN
#
#    TTF_Price
# 0      21.00
# 1      22.20
# 2      22.85
# 3      26.00
# 4      26.33

# %%
df_all.describe()
# Out:
#                                 Date  Brent_Price  CBOE_Vol.   CBOE_Price  \
# count                           4307   4265.00000        0.0  4189.000000
# mean   2017-04-04 19:51:35.147434496     77.17793        NaN    19.243275
# min              2009-01-01 00:00:00     19.33000        NaN     9.140000
# 25%              2013-02-20 12:00:00     59.48000        NaN    13.840000
# 50%              2017-04-04 00:00:00     75.15000        NaN    17.150000
# 75%              2021-05-19 12:00:00     97.11000        NaN    22.270000
# max              2025-07-07 00:00:00    127.98000        NaN    82.690000
# std                              NaN     23.53985        NaN     7.739013
#
#         Coal_Price  HenryHub_Price    JKM_Price    NBP_Price    PSV_Price  \
# count  4233.000000     4162.000000  2802.000000  4088.000000  3442.000000
# mean    112.900449        3.386535    11.995131    68.017101    34.187542
# min      48.500000        1.210000     1.995000     8.500000     4.150000
# 25%      72.000000        2.580000     6.200000    39.887500    18.600000
# 50%      93.750000        3.060000     9.365000    54.800000    25.350000
# 75%     120.850000        3.970000    13.495000    69.525000    34.250000
# max     457.800000       23.860000    69.955000   570.000000   310.000000
# std      74.698211        1.333616     9.385830    55.742973    32.768922
#
#          TTF_Price
# count  4246.000000
# mean     29.469475
# min       3.100000
# 25%      15.820000
# 50%      21.800000
# 75%      27.437500
# max     330.000000
# std      30.719771

# %% [markdown]
# Defining a plotting function

# %%
import plotly.graph_objects as go
import pandas as pd

def plot_lstm_forecast_aligned_to_forecast_date(
    df_full,
    forecast_dates,
    y_pred_inv,
    y_true_inv,
    horizon_days,
    title='TTF Price Forecast (Aligned to Forecast Date)'
):
    """
    Plots historical TTF prices, and shows predicted & actual target prices on the forecast date.

    Parameters:
    - df_full: DataFrame with 'TTF_Price' and datetime index (historical)
    - forecast_dates: dates when forecasts were made
    - y_pred_inv: predicted prices for target dates (already inverse-transformed)
    - y_true_inv: actual target prices (already inverse-transformed)
    - horizon_days: how far ahead the forecast is (e.g., 30 for 1-month)
    - title: chart title
    """

    # Convert inputs to pandas Series for indexing
    forecast_dates = pd.to_datetime(forecast_dates)
    y_pred_series = pd.Series(y_pred_inv.flatten(), index=forecast_dates)

    # Shift actual target values back to the forecast date
    actual_target_dates = forecast_dates + pd.Timedelta(days=horizon_days)
    y_true_series = pd.Series(y_true_inv.flatten(), index=actual_target_dates)
    y_true_aligned = y_true_series.shift(-horizon_days, freq='D')  # move back to forecast date

    # Start building the plot
    fig = go.Figure()

    # Historical TTF price
    fig.add_trace(go.Scatter(
        x=df_full.index,
        y=df_full['TTF_Price'],
        mode='lines',
        name='Historical TTF Price',
        line=dict(color='lightgray'),
        opacity=0.5
    ))

    # Predicted target prices (plotted on forecast date)
    fig.add_trace(go.Scatter(
        x=y_pred_series.index,
        y=y_pred_series.values,
        mode='lines+markers',
        name=f'Predicted TTF (+{horizon_days}D)',
        marker=dict(size=2.5),
        line=dict(color='orange')
    ))

    # Actual future prices aligned to forecast date
    fig.add_trace(go.Scatter(
        x=y_true_aligned.index,
        y=y_true_aligned.values,
        mode='lines+markers',
        name=f'Actual TTF (+{horizon_days}D)',
        marker=dict(size=2.5),
        line=dict(color='blue')
    ))

    # Layout
    fig.update_layout(
        title=f'LSTM Forecast vs Actual TTF  ({horizon_days}-Day Horizon, Aligned to Forecast Date)',
        xaxis_title='Forecast Date',
        yaxis_title='TTF Price (EUR/MWh)',
        hovermode='x unified',
        xaxis=dict(tickangle=-45),
        height=600
    )

    fig.show()

# %%
def forecast_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)

    return {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R²": r2
    }

# %%
df_ttf = df_all[['Date', 'TTF_Price']].dropna()
df_ttf.set_index('Date', inplace=True) # Sets 'Date' as the DataFrame index so it behaves like a time series.
df_ttf = df_ttf.asfreq('D').interpolate() # Fills any gaps (e.g., holidays or weekends) using linear interpolation

# %% [markdown]
# ## Tips for LSTM Success
#
# | Tip                    | Why                                                          |
# | ---------------------- | ------------------------------------------------------------ |
# | Normalize data         | LSTMs perform better when values are between 0 and 1         |
# | Use more lags          | Try 60, 90, or 180-day windows                               |
# | Tune architecture      | Try stacked LSTMs, dropout, or learning rate schedules       |
# | Add exogenous features | Include Brent, Coal, NBP, etc., as additional input channels |

# %%
# Normalize the data
scaler = MinMaxScaler()
scaled = scaler.fit_transform(df_ttf[['TTF_Price']]) # Scales all prices to between 0 and 1 using Min-Max scaling, This helps LSTM learn better and converge faster.

# Create supervised Sequences

def create_sequences(data, window_size=30, horizon=30): # window_size=30: Use last 30 days of data as input/horizon=30: Predict the price 30 day into the future
    X, y = [], []
    for i in range(len(data) - window_size - horizon + 1):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size+horizon-1])
    return np.array(X), np.array(y)

# %% [markdown]
# use 30 past days to predict 30 day ahead

# %%
window_size = 90
horizon_days = 30
X, y = create_sequences(scaled, window_size=window_size, horizon=horizon_days) # Generates many (X, y) pairs for the entire dataset.

# Train/test split
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
y_test.shape
# Out:
# (1125, 1)

# %%
# Build and Train the LSTM Model

# Build model
model_base = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])
model_base.compile(optimizer='adam', loss='mse',metrics=[
        MeanAbsoluteError(name='mae'),
        RootMeanSquaredError(name='rmse'),
        MeanAbsolutePercentageError(name='mape')
    ])

# Train model
history = model_base.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 4.4838e-04 - mae: 0.0151 - mape: 9140.2646 - rmse: 0.0199 - val_loss: 0.0056 - val_mae: 0.0449 - val_mape: 24.5383 - val_rmse: 0.0745
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.9313e-05 - mae: 0.0060 - mape: 1036.0405 - rmse: 0.0083 - val_loss: 0.0059 - val_mae: 0.0455 - val_mape: 24.4881 - val_rmse: 0.0770
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5814e-05 - mae: 0.0060 - mape: 178.5575 - rmse: 0.0081 - val_loss: 0.0055 - val_mae: 0.0431 - val_mape: 22.6910 - val_rmse: 0.0741
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8896e-05 - mae: 0.0056 - mape: 1782.1958 - rmse: 0.0083 - val_loss: 0.0063 - val_mae: 0.0464 - val_mape: 24.8369 - val_rmse: 0.0791
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.1898e-05 - mae: 0.0059 - mape: 4679.5322 - rmse: 0.0089 - val_loss: 0.0063 - val_mae: 0.0474 - val_mape: 26.2194 - val_rmse: 0.0796
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.0018e-05 - mae: 0.0057 - mape: 1293.4963 - rmse: 0.0083 - val_loss: 0.0057 - val_mae: 0.0432 - val_mape: 22.6778 - val_rmse: 0.0754
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.0745e-05 - mae: 0.0055 - mape: 5903.2217 - rmse: 0.0078 - val_loss: 0.0065 - val_mae: 0.0465 - val_mape: 24.2868 - val_rmse: 0.0803
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7306e-05 - mae: 0.0057 - mape: 7767.9829 - rmse: 0.0082 - val_loss: 0.0063 - val_mae: 0.0467 - val_mape: 25.4885 - val_rmse: 0.0795
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.1185e-05 - mae: 0.0058 - mape: 6133.2324 - rmse: 0.0084 - val_loss: 0.0066 - val_mae: 0.0471 - val_mape: 24.4151 - val_rmse: 0.0814
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.3948e-05 - mae: 0.0055 - mape: 822.1699 - rmse: 0.0073 - val_loss: 0.0062 - val_mae: 0.0451 - val_mape: 23.5198 - val_rmse: 0.0790
# Epoch 11/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3849e-05 - mae: 0.0057 - mape: 4203.4507 - rmse: 0.0085 - val_loss: 0.0072 - val_mae: 0.0502 - val_mape: 26.1724 - val_rmse: 0.0847
# Epoch 12/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.0237e-05 - mae: 0.0054 - mape: 5377.9126 - rmse: 0.0077 - val_loss: 0.0067 - val_mae: 0.0477 - val_mape: 25.0217 - val_rmse: 0.0818
# Epoch 13/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4532e-05 - mae: 0.0058 - mape: 2781.0208 - rmse: 0.0080 - val_loss: 0.0070 - val_mae: 0.0486 - val_mape: 24.8417 - val_rmse: 0.0834
# Epoch 14/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.4067e-05 - mae: 0.0054 - mape: 14972.0566 - rmse: 0.0073 - val_loss: 0.0069 - val_mae: 0.0472 - val_mape: 23.1162 - val_rmse: 0.0829
# Epoch 15/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.4841e-05 - mae: 0.0055 - mape: 278.3316 - rmse: 0.0080 - val_loss: 0.0074 - val_mae: 0.0506 - val_mape: 25.5842 - val_rmse: 0.0858
# Epoch 16/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6207e-05 - mae: 0.0054 - mape: 558.5415 - rmse: 0.0081 - val_loss: 0.0073 - val_mae: 0.0506 - val_mape: 26.2151 - val_rmse: 0.0852
# Epoch 17/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.2145e-05 - mae: 0.0057 - mape: 6359.4995 - rmse: 0.0079 - val_loss: 0.0076 - val_mae: 0.0522 - val_mape: 26.4245 - val_rmse: 0.0874
# Epoch 18/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6895e-05 - mae: 0.0054 - mape: 1797.7209 - rmse: 0.0081 - val_loss: 0.0073 - val_mae: 0.0502 - val_mape: 25.2726 - val_rmse: 0.0855
# Epoch 19/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.7538e-05 - mae: 0.0054 - mape: 4733.3569 - rmse: 0.0076 - val_loss: 0.0076 - val_mae: 0.0527 - val_mape: 27.8356 - val_rmse: 0.0871
# Epoch 20/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4591e-05 - mae: 0.0057 - mape: 8019.3369 - rmse: 0.0080 - val_loss: 0.0072 - val_mae: 0.0498 - val_mape: 25.2909 - val_rmse: 0.0849

# %%
# Evaluate and Inverse Scale Predictions
# Predict
y_pred = model_base.predict(X_test)

# Inverse scale
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# {'MAE': 17.11815686765768,
#  'MSE': 1225.1863253028885,
#  'RMSE': np.float64(35.00266168883287),
#  'R²': 0.48791923180870667}

# %%
# Evaluate and Inverse Scale Predictions
# Predict

# Calculate forecast dates based on the test set
# The first forecast date corresponds to the end of the first window in the test set
# The last forecast date corresponds to the end of the last window in the test set
forecast_dates = df_ttf.index[window_size - 1 : -(horizon_days)]
forecast_dates = forecast_dates[split:]

plot_lstm_forecast_aligned_to_forecast_date(
    df_full=df_ttf,
    forecast_dates=forecast_dates,
    y_pred_inv=y_pred_inv,
    y_true_inv=y_test_inv,
    horizon_days=30
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e66060a9-5b09-4923-b5d1-71e67727252f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e66060a9-5b09-4923-b5d1-71e67727252f")) {                    Plotly.newPlot(                        "e66060a9-5b09-4923-b5d1-71e67727252f",                        [{"line":{"color":"lightgray"},"mode":"lines","name":"Historical TTF Price","opacity":0.5,"x":["2009-01-01T00:00:00","2009-01-02T00:00:00","2009-01-03T00:00:00","2009-01-04T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-10T00:00:00","2009-01-11T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-17T00:00:00","2009-01-18T00:00:00","2009-01-19T00:00:00","2009-01-20T00:00:00","2009-01-21T00:00:00","2009-01-22T00:00:00","2009-01-23T00:00:00","2009-01-24T00:00:00","2009-01-25T00:00:00","2009-01-26T00:00:00","2009-01-27T00:00:00","2009-01-28T00:00:00","2009-01-29T00:00:00","2009-01-30T00:00:00","2009-01-31T00:00:00","2009-02-01T00:00:00","2009-02-02T00:00:00","2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-07T00:00:00","2009-02-08T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-14T00:00:00","2009-02-15T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-21T00:00:00","2009-02-22T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-02-28T00:00:00","2009-03-01T00:00:00","2009-03-02T00:00:00","2009-03-03T00:00:00","2009-03-04T00:00:00","2009-03-05T00:00:00","2009-03-06T00:00:00","2009-03-07T00:00:00","2009-03-08T00:00:00","2009-03-09T00:00:00","2009-03-10T00:00:00","2009-03-11T00:00:00","2009-03-12T00:00:00","2009-03-13T00:00:00","2009-03-14T00:00:00","2009-03-15T00:00:00","2009-03-16T00:00:00","2009-03-17T00:00:00","2009-03-18T00:00:00","2009-03-19T00:00:00","2009-03-20T00:00:00","2009-03-21T00:00:00","2009-03-22T00:00:00","2009-03-23T00:00:00","2009-03-24T00:00:00","2009-03-25T00:00:00","2009-03-26T00:00:00","2009-03-27T00:00:00","2009-03-28T00:00:00","2009-03-29T00:00:00","2009-03-30T00:00:00","2009-03-31T00:00:00","2009-04-01T00:00:00","2009-04-02T00:00:00","2009-04-03T00:00:00","2009-04-04T00:00:00","2009-04-05T00:00:00","2009-04-06T00:00:00","2009-04-07T00:00:00","2009-04-08T00:00:00","2009-04-09T00:00:00","2009-04-10T00:00:00","2009-04-11T00:00:00","2009-04-12T00:00:00","2009-04-13T00:00:00","2009-04-14T00:00:00","2009-04-15T00:00:00","2009-04-16T00:00:00","2009-04-17T00:00:00","2009-04-18T00:00:00","2009-04-19T00:00:00","2009-04-20T00:00:00","2009-04-21T00:00:00","2009-04-22T00:00:00","2009-04-23T00:00:00","2009-04-24T00:00:00","2009-04-25T00:00:00","2009-04-26T00:00:00","2009-04-27T00:00:00","2009-04-28T00:00:00","2009-04-29T00:00:00","2009-04-30T00:00:00","2009-05-01T00:00:00","2009-05-02T00:00:00","2009-05-03T00:00:00","2009-05-04T00:00:00","2009-05-05T00:00:00","2009-05-06T00:00:00","2009-05-07T00:00:00","2009-05-08T00:00:00","2009-05-09T00:00:00","2009-05-10T00:00:00","2009-05-11T00:00:00","2009-05-12T00:00:00","2009-05-13T00:00:00","2009-05-14T00:00:00","2009-05-15T00:00:00","2009-05-16T00:00:00","2009-05-17T00:00:00","2009-05-18T00:00:00","2009-05-19T00:00:00","2009-05-20T00:00:00","2009-05-21T00:00:00","2009-05-22T00:00:00","2009-05-23T00:00:00","2009-05-24T00:00:00","2009-05-25T00:00:00","2009-05-26T00:00:00","2009-05-27T00:00:00","2009-05-28T00:00:00","2009-05-29T00:00:00","2009-05-30T00:00:00","2009-05-31T00:00:00","2009-06-01T00:00:00 ...

# %% [markdown]
# use 90 days to predict 90 days ahead

# %%
window_size = 365
horizon_days = 90
X, y = create_sequences(scaled, window_size=window_size, horizon=horizon_days) # Generates many (X, y) pairs for the entire dataset.

# Train/test split
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Build and Train the LSTM Model

# Build model
model = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')

# Train model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 4.3242e-04 - val_loss: 0.0122
# Epoch 2/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.2808e-04 - val_loss: 0.0123
# Epoch 3/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.3021e-04 - val_loss: 0.0114
# Epoch 4/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.2064e-04 - val_loss: 0.0092
# Epoch 5/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.9728e-04 - val_loss: 0.0120
# Epoch 6/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2121e-04 - val_loss: 0.0124
# Epoch 7/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 1.1665e-04 - val_loss: 0.0113
# Epoch 8/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1525e-04 - val_loss: 0.0108
# Epoch 9/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.2021e-04 - val_loss: 0.0117
# Epoch 10/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.1466e-04 - val_loss: 0.0118
# Epoch 11/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.2172e-04 - val_loss: 0.0114
# Epoch 12/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2552e-04 - val_loss: 0.0110
# Epoch 13/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1715e-04 - val_loss: 0.0112
# Epoch 14/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.4282e-04 - val_loss: 0.0119
# Epoch 15/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 1.2245e-04 - val_loss: 0.0118
# Epoch 16/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1.3786e-04 - val_loss: 0.0110
# Epoch 17/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.3558e-04 - val_loss: 0.0117
# Epoch 18/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.2426e-04 - val_loss: 0.0113
# Epoch 19/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.1417e-04 - val_loss: 0.0120
# Epoch 20/20
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.3210e-04 - val_loss: 0.0110

# %%
# Evaluate and Inverse Scale Predictions
# Predict
y_pred = model.predict(X_test)

# Inverse scale
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# {'MAE': 25.14174479331182,
#  'MSE': 1987.2337487631762,
#  'RMSE': np.float64(44.57840002471125),
#  'R²': 0.1897730075260815}

# %%
# Evaluate and Inverse Scale Predictions
# Predict
y_pred = model.predict(X_test)

# Inverse scale
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

# Calculate forecast dates based on the test set
# The first forecast date corresponds to the end of the first window in the test set
# The last forecast date corresponds to the end of the last window in the test set
forecast_dates = df_ttf.index[window_size - 1 : -(horizon_days)]
forecast_dates = forecast_dates[split:]

plot_lstm_forecast_aligned_to_forecast_date(
    df_full=df_ttf,
    forecast_dates=forecast_dates,
    y_pred_inv=y_pred_inv,
    y_true_inv=y_test_inv,
    horizon_days=horizon_days)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b44e63de-15c2-4e07-a262-ac08b2eeac4d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b44e63de-15c2-4e07-a262-ac08b2eeac4d")) {                    Plotly.newPlot(                        "b44e63de-15c2-4e07-a262-ac08b2eeac4d",                        [{"line":{"color":"lightgray"},"mode":"lines","name":"Historical TTF Price","opacity":0.5,"x":["2009-01-01T00:00:00","2009-01-02T00:00:00","2009-01-03T00:00:00","2009-01-04T00:00:00","2009-01-05T00:00:00","2009-01-06T00:00:00","2009-01-07T00:00:00","2009-01-08T00:00:00","2009-01-09T00:00:00","2009-01-10T00:00:00","2009-01-11T00:00:00","2009-01-12T00:00:00","2009-01-13T00:00:00","2009-01-14T00:00:00","2009-01-15T00:00:00","2009-01-16T00:00:00","2009-01-17T00:00:00","2009-01-18T00:00:00","2009-01-19T00:00:00","2009-01-20T00:00:00","2009-01-21T00:00:00","2009-01-22T00:00:00","2009-01-23T00:00:00","2009-01-24T00:00:00","2009-01-25T00:00:00","2009-01-26T00:00:00","2009-01-27T00:00:00","2009-01-28T00:00:00","2009-01-29T00:00:00","2009-01-30T00:00:00","2009-01-31T00:00:00","2009-02-01T00:00:00","2009-02-02T00:00:00","2009-02-03T00:00:00","2009-02-04T00:00:00","2009-02-05T00:00:00","2009-02-06T00:00:00","2009-02-07T00:00:00","2009-02-08T00:00:00","2009-02-09T00:00:00","2009-02-10T00:00:00","2009-02-11T00:00:00","2009-02-12T00:00:00","2009-02-13T00:00:00","2009-02-14T00:00:00","2009-02-15T00:00:00","2009-02-16T00:00:00","2009-02-17T00:00:00","2009-02-18T00:00:00","2009-02-19T00:00:00","2009-02-20T00:00:00","2009-02-21T00:00:00","2009-02-22T00:00:00","2009-02-23T00:00:00","2009-02-24T00:00:00","2009-02-25T00:00:00","2009-02-26T00:00:00","2009-02-27T00:00:00","2009-02-28T00:00:00","2009-03-01T00:00:00","2009-03-02T00:00:00","2009-03-03T00:00:00","2009-03-04T00:00:00","2009-03-05T00:00:00","2009-03-06T00:00:00","2009-03-07T00:00:00","2009-03-08T00:00:00","2009-03-09T00:00:00","2009-03-10T00:00:00","2009-03-11T00:00:00","2009-03-12T00:00:00","2009-03-13T00:00:00","2009-03-14T00:00:00","2009-03-15T00:00:00","2009-03-16T00:00:00","2009-03-17T00:00:00","2009-03-18T00:00:00","2009-03-19T00:00:00","2009-03-20T00:00:00","2009-03-21T00:00:00","2009-03-22T00:00:00","2009-03-23T00:00:00","2009-03-24T00:00:00","2009-03-25T00:00:00","2009-03-26T00:00:00","2009-03-27T00:00:00","2009-03-28T00:00:00","2009-03-29T00:00:00","2009-03-30T00:00:00","2009-03-31T00:00:00","2009-04-01T00:00:00","2009-04-02T00:00:00","2009-04-03T00:00:00","2009-04-04T00:00:00","2009-04-05T00:00:00","2009-04-06T00:00:00","2009-04-07T00:00:00","2009-04-08T00:00:00","2009-04-09T00:00:00","2009-04-10T00:00:00","2009-04-11T00:00:00","2009-04-12T00:00:00","2009-04-13T00:00:00","2009-04-14T00:00:00","2009-04-15T00:00:00","2009-04-16T00:00:00","2009-04-17T00:00:00","2009-04-18T00:00:00","2009-04-19T00:00:00","2009-04-20T00:00:00","2009-04-21T00:00:00","2009-04-22T00:00:00","2009-04-23T00:00:00","2009-04-24T00:00:00","2009-04-25T00:00:00","2009-04-26T00:00:00","2009-04-27T00:00:00","2009-04-28T00:00:00","2009-04-29T00:00:00","2009-04-30T00:00:00","2009-05-01T00:00:00","2009-05-02T00:00:00","2009-05-03T00:00:00","2009-05-04T00:00:00","2009-05-05T00:00:00","2009-05-06T00:00:00","2009-05-07T00:00:00","2009-05-08T00:00:00","2009-05-09T00:00:00","2009-05-10T00:00:00","2009-05-11T00:00:00","2009-05-12T00:00:00","2009-05-13T00:00:00","2009-05-14T00:00:00","2009-05-15T00:00:00","2009-05-16T00:00:00","2009-05-17T00:00:00","2009-05-18T00:00:00","2009-05-19T00:00:00","2009-05-20T00:00:00","2009-05-21T00:00:00","2009-05-22T00:00:00","2009-05-23T00:00:00","2009-05-24T00:00:00","2009-05-25T00:00:00","2009-05-26T00:00:00","2009-05-27T00:00:00","2009-05-28T00:00:00","2009-05-29T00:00:00","2009-05-30T00:00:00","2009-05-31T00:00:00","2009-06-01T00:00:00 ...

# %% [markdown]
# ## Trying to add sin_day and cos_day feature on top of the TTF price or adding layers to LSTM model to see if will increase the performance....

# %%
# @title Filling missing values

def fill_missing_dates(df, date_column='date'):
    df[date_column] = pd.to_datetime(df[date_column])
    df = df.set_index(date_column).sort_index()

    # Reindex to continuous daily frequency
    full_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
    df = df.reindex(full_range)

    # Optionally interpolate missing values
    df.interpolate(method='linear', inplace=True)

    # Reset index and rename
    df = df.reset_index().rename(columns={'index': date_column})
    return df

# %%
df = df_all[['Date', 'TTF_Price']].dropna()
df = fill_missing_dates(df_ttf, date_column='Date')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['dayofyear'] = df['Date'].dt.dayofyear
df['sin_day'] = np.sin(2 * np.pi * df['dayofyear'] / 365) # Smooth annual cycles,Ideal for yearly seasonality
df['cos_day'] = np.cos(2 * np.pi * df['dayofyear'] / 365) # sin_day and cos_day Encode Full Cycles, like latitude and longitude
df.head()
# Out:
#         Date  TTF_Price  dayofyear   sin_day   cos_day
# 0 2009-01-01  21.000000          1  0.017213  0.999852
# 1 2009-01-02  22.200000          2  0.034422  0.999407
# 2 2009-01-03  22.416667          3  0.051620  0.998667
# 3 2009-01-04  22.633333          4  0.068802  0.997630
# 4 2009-01-05  22.850000          5  0.085965  0.996298

# %%
def create_sequences_multifeature(data, window_size=30, horizon=30):
    X, y = [], []
    for i in range(len(data) - window_size - horizon + 1):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size+horizon-1][0])  # <== ONLY take the first feature (TTF_Price)
    return np.array(X), np.array(y)

# %%
# Normalize the data

features = df[['TTF_Price', 'sin_day', 'cos_day']]
scaler = MinMaxScaler()
scaled = scaler.fit_transform(features)

window_size = 90
horizon_days = 30
test_split=0.2

X, y = create_sequences_multifeature(scaled, window_size=window_size, horizon=horizon_days)
split = int(len(X) * (1 - test_split))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (4716, 90, 3)
# X_test shape: (1180, 90, 3)
# y_train shape: (4716,)
# y_test shape: (1180,)

# %%
# Build and Train the LSTM Model

# Build model
model_3_features = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])
model_3_features.compile(optimizer=Adam(learning_rate=0.0005),
                         loss='mse')

# Train model
history = model_3_features.fit(X_train, y_train, epochs=50, callbacks=[EarlyStopping(patience=5)], batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1162 - val_loss: 0.0919
# Epoch 2/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1003 - val_loss: 0.0919
# Epoch 3/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0991 - val_loss: 0.0918
# Epoch 4/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0992 - val_loss: 0.0918
# Epoch 5/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1001 - val_loss: 0.0917
# Epoch 6/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0984 - val_loss: 0.0917
# Epoch 7/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0996 - val_loss: 0.0917
# Epoch 8/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0977 - val_loss: 0.0917
# Epoch 9/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0975 - val_loss: 0.0916
# Epoch 10/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1008 - val_loss: 0.0916
# Epoch 11/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0996 - val_loss: 0.0916
# Epoch 12/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1006 - val_loss: 0.0916
# Epoch 13/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0993 - val_loss: 0.0916
# Epoch 14/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1007 - val_loss: 0.0917
# Epoch 15/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0998 - val_loss: 0.0916
# Epoch 16/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0979 - val_loss: 0.0916
# Epoch 17/50
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0999 - val_loss: 0.0917

# %%
y_pred = model_3_features.predict(X_test).flatten()
y_pred.shape
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# (1180,)

# %%
## Evaluate the model
y_pred = model_3_features.predict(X_test).flatten()

# Inverse scale: y_test and y_pred go back to original TTF_Price
y_test_inv = scaler.inverse_transform(
    np.hstack([y_test.reshape(-1, 1), np.zeros((len(y_test), 2))])
)[:, 0]

y_pred_inv = scaler.inverse_transform(
    np.hstack([y_pred.reshape(-1, 1), np.zeros((len(y_pred), 2))])
)[:, 0]

mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)


forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'MAE': 88.33323507304198,
#  'MSE': 10489.265683176445,
#  'RMSE': np.float64(102.41711616315139),
#  'R²': -3.3841096801955155}

# %%
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam

model_3_features = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dense(1)
])

model_3_features.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='mse',
    metrics=[
        MeanAbsoluteError(name='mae'),
        RootMeanSquaredError(name='rmse'),
        MeanAbsolutePercentageError(name='mape')
    ]
)

# Train model with EarlyStopping
history = model_3_features.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[EarlyStopping(patience=5)],
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 4.4882e-04 - mae: 0.0154 - mape: 1226.2416 - rmse: 0.0201 - val_loss: 0.0118 - val_mae: 0.0797 - val_mape: 36.5270 - val_rmse: 0.1088
# Epoch 2/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.3034e-04 - mae: 0.0089 - mape: 12747.6729 - rmse: 0.0114 - val_loss: 0.0121 - val_mae: 0.0809 - val_mape: 36.3386 - val_rmse: 0.1100
# Epoch 3/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.2683e-04 - mae: 0.0089 - mape: 2965.6589 - rmse: 0.0113 - val_loss: 0.0115 - val_mae: 0.0785 - val_mape: 36.4855 - val_rmse: 0.1071
# Epoch 4/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2157e-04 - mae: 0.0089 - mape: 705.4146 - rmse: 0.0110 - val_loss: 0.0106 - val_mae: 0.0739 - val_mape: 33.6218 - val_rmse: 0.1030
# Epoch 5/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 1.2409e-04 - mae: 0.0091 - mape: 8354.4854 - rmse: 0.0111 - val_loss: 0.0126 - val_mae: 0.0844 - val_mape: 39.2331 - val_rmse: 0.1123
# Epoch 6/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3024e-04 - mae: 0.0090 - mape: 4921.7231 - rmse: 0.0114 - val_loss: 0.0111 - val_mae: 0.0770 - val_mape: 36.0286 - val_rmse: 0.1052
# Epoch 7/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.1543e-04 - mae: 0.0086 - mape: 6368.6689 - rmse: 0.0107 - val_loss: 0.0110 - val_mae: 0.0764 - val_mape: 35.2252 - val_rmse: 0.1047
# Epoch 8/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 1.1549e-04 - mae: 0.0086 - mape: 7188.9307 - rmse: 0.0107 - val_loss: 0.0116 - val_mae: 0.0794 - val_mape: 36.1626 - val_rmse: 0.1078
# Epoch 9/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - loss: 1.3057e-04 - mae: 0.0089 - mape: 12885.5146 - rmse: 0.0114 - val_loss: 0.0111 - val_mae: 0.0772 - val_mape: 35.8148 - val_rmse: 0.1053

# %%
## Evaluate the model
y_pred = model_3_features.predict(X_test).flatten()

# Inverse scale: y_test and y_pred go back to original TTF_Price
y_test_inv = scaler.inverse_transform(
    np.hstack([y_test.reshape(-1, 1), np.zeros((len(y_test), 2))])
)[:, 0]

y_pred_inv = scaler.inverse_transform(
    np.hstack([y_pred.reshape(-1, 1), np.zeros((len(y_pred), 2))])
)[:, 0]

mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)


forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# {'MAE': 25.808492264481032,
#  'MSE': 2037.015877077372,
#  'RMSE': np.float64(45.13331227682466),
#  'R²': 0.16947603736438555}

# %% [markdown]
# ## trying to add other features to the LSTM model

# %%
df_other_features = df_all[['Date', 'TTF_Price', 'NBP_Price','Coal_Price', 'HenryHub_Price']].dropna()
df_other_features = fill_missing_dates(df_other_features, date_column='Date')
df_other_features['Date'] = pd.to_datetime(df_other_features['Date'])
df_other_features.set_index('Date', inplace=True)
df_other_features.head()
# Out:
#             TTF_Price  NBP_Price  Coal_Price  HenryHub_Price
# Date
# 2009-08-03       8.85      20.25       70.63            3.43
# 2009-08-04       9.45      22.90       73.75            3.53
# 2009-08-05       9.25      22.50       73.65            3.61
# 2009-08-06       9.25      23.55       74.25            3.78
# 2009-08-07       9.23      23.25       74.05            3.57

# %%
df_other_features.describe()
# Out:
#          TTF_Price    NBP_Price   Coal_Price  HenryHub_Price
# count  5801.000000  5801.000000  5801.000000     5801.000000
# mean     30.115352    68.039089   114.310134        3.366995
# std      30.945594    55.259784    75.461088        1.341175
# min       3.100000     8.500000    48.750000        1.210000
# 25%      16.440000    40.000000    73.200000        2.550000
# 50%      22.100000    55.016667    94.600000        3.006667
# 75%      27.980000    69.916667   121.500000        3.960000
# max     330.000000   570.000000   450.250000       23.860000

# %%
# Normalize the data

features = df_other_features[['TTF_Price', 'NBP_Price','Coal_Price', 'HenryHub_Price']]
scaler = MinMaxScaler()
scaled = scaler.fit_transform(features)

window_size = 90
horizon_days = 30
test_split=0.2

X, y = create_sequences_multifeature(scaled, window_size=window_size, horizon=horizon_days)
split = int(len(X) * (1 - test_split))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (4545, 90, 4)
# X_test shape: (1137, 90, 4)
# y_train shape: (4545,)
# y_test shape: (1137,)

# %%
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam

model_other_features = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),  # Preferred input shape
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(64),
    Dense(1)
])

model_other_features.compile(
    optimizer=Adam(),
    loss='mse',
    metrics=[
        MeanAbsoluteError(name='mae'),
        RootMeanSquaredError(name='rmse'),
        MeanAbsolutePercentageError(name='mape')
    ]
)

# Train model with EarlyStopping
history = model_other_features.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[EarlyStopping(patience=5)],
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 1.9180e-04 - mae: 0.0100 - mape: 1958.1541 - rmse: 0.0132 - val_loss: 0.0070 - val_mae: 0.0513 - val_mape: 24.2942 - val_rmse: 0.0840
# Epoch 2/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 6.9263e-05 - mae: 0.0064 - mape: 419.1206 - rmse: 0.0083 - val_loss: 0.0068 - val_mae: 0.0507 - val_mape: 24.3516 - val_rmse: 0.0827
# Epoch 3/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.9919e-05 - mae: 0.0062 - mape: 6434.1777 - rmse: 0.0083 - val_loss: 0.0081 - val_mae: 0.0566 - val_mape: 26.9663 - val_rmse: 0.0899
# Epoch 4/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.6373e-05 - mae: 0.0064 - mape: 4383.3228 - rmse: 0.0092 - val_loss: 0.0074 - val_mae: 0.0520 - val_mape: 24.3943 - val_rmse: 0.0858
# Epoch 5/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.7815e-05 - mae: 0.0060 - mape: 6198.8853 - rmse: 0.0082 - val_loss: 0.0071 - val_mae: 0.0497 - val_mape: 22.8885 - val_rmse: 0.0840
# Epoch 6/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.0049e-05 - mae: 0.0062 - mape: 4781.6641 - rmse: 0.0084 - val_loss: 0.0086 - val_mae: 0.0589 - val_mape: 26.7551 - val_rmse: 0.0930
# Epoch 7/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.1456e-05 - mae: 0.0059 - mape: 751.3668 - rmse: 0.0078 - val_loss: 0.0088 - val_mae: 0.0602 - val_mape: 27.9033 - val_rmse: 0.0936

# %%
## Evaluate the model
y_pred = model_other_features.predict(X_test).flatten()

# 2. Inverse scale both y_test and y_pred (only the TTF_Price column)
y_test_inv = scaler.inverse_transform(
    np.hstack([y_test.reshape(-1, 1), np.zeros((len(y_test), scaled.shape[1] - 1))])
)[:, 0]

y_pred_inv = scaler.inverse_transform(
    np.hstack([y_pred.reshape(-1, 1), np.zeros((len(y_pred), scaled.shape[1] - 1))])
)[:, 0]

forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'MAE': 18.825039787378255,
#  'MSE': 1439.4177450928105,
#  'RMSE': np.float64(37.93965926432143),
#  'R²': 0.4044353911311346}

# %%
y_pred_inv
# Out:
# array([73.12252232, 72.69573791, 72.55842882, ..., 30.23851273,
#        30.46255336, 30.66853161])

# %%
# Calculate forecast dates based on the test set
# The first forecast date corresponds to the end of the first window in the test set
# The last forecast date corresponds to the end of the last window in the test set
forecast_dates = df_other_features.index[window_size - 1 : -(horizon_days)]
forecast_dates = forecast_dates[split:]

plot_lstm_forecast_aligned_to_forecast_date(
    df_full=df_other_features,
    forecast_dates=forecast_dates,
    y_pred_inv=y_pred_inv,
    y_true_inv=y_test_inv,
    horizon_days=horizon_days)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b157f53e-d3bb-45dc-a024-8eaa25e5950a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b157f53e-d3bb-45dc-a024-8eaa25e5950a")) {                    Plotly.newPlot(                        "b157f53e-d3bb-45dc-a024-8eaa25e5950a",                        [{"line":{"color":"lightgray"},"mode":"lines","name":"Historical TTF Price","opacity":0.5,"x":["2009-08-03T00:00:00","2009-08-04T00:00:00","2009-08-05T00:00:00","2009-08-06T00:00:00","2009-08-07T00:00:00","2009-08-08T00:00:00","2009-08-09T00:00:00","2009-08-10T00:00:00","2009-08-11T00:00:00","2009-08-12T00:00:00","2009-08-13T00:00:00","2009-08-14T00:00:00","2009-08-15T00:00:00","2009-08-16T00:00:00","2009-08-17T00:00:00","2009-08-18T00:00:00","2009-08-19T00:00:00","2009-08-20T00:00:00","2009-08-21T00:00:00","2009-08-22T00:00:00","2009-08-23T00:00:00","2009-08-24T00:00:00","2009-08-25T00:00:00","2009-08-26T00:00:00","2009-08-27T00:00:00","2009-08-28T00:00:00","2009-08-29T00:00:00","2009-08-30T00:00:00","2009-08-31T00:00:00","2009-09-01T00:00:00","2009-09-02T00:00:00","2009-09-03T00:00:00","2009-09-04T00:00:00","2009-09-05T00:00:00","2009-09-06T00:00:00","2009-09-07T00:00:00","2009-09-08T00:00:00","2009-09-09T00:00:00","2009-09-10T00:00:00","2009-09-11T00:00:00","2009-09-12T00:00:00","2009-09-13T00:00:00","2009-09-14T00:00:00","2009-09-15T00:00:00","2009-09-16T00:00:00","2009-09-17T00:00:00","2009-09-18T00:00:00","2009-09-19T00:00:00","2009-09-20T00:00:00","2009-09-21T00:00:00","2009-09-22T00:00:00","2009-09-23T00:00:00","2009-09-24T00:00:00","2009-09-25T00:00:00","2009-09-26T00:00:00","2009-09-27T00:00:00","2009-09-28T00:00:00","2009-09-29T00:00:00","2009-09-30T00:00:00","2009-10-01T00:00:00","2009-10-02T00:00:00","2009-10-03T00:00:00","2009-10-04T00:00:00","2009-10-05T00:00:00","2009-10-06T00:00:00","2009-10-07T00:00:00","2009-10-08T00:00:00","2009-10-09T00:00:00","2009-10-10T00:00:00","2009-10-11T00:00:00","2009-10-12T00:00:00","2009-10-13T00:00:00","2009-10-14T00:00:00","2009-10-15T00:00:00","2009-10-16T00:00:00","2009-10-17T00:00:00","2009-10-18T00:00:00","2009-10-19T00:00:00","2009-10-20T00:00:00","2009-10-21T00:00:00","2009-10-22T00:00:00","2009-10-23T00:00:00","2009-10-24T00:00:00","2009-10-25T00:00:00","2009-10-26T00:00:00","2009-10-27T00:00:00","2009-10-28T00:00:00","2009-10-29T00:00:00","2009-10-30T00:00:00","2009-10-31T00:00:00","2009-11-01T00:00:00","2009-11-02T00:00:00","2009-11-03T00:00:00","2009-11-04T00:00:00","2009-11-05T00:00:00","2009-11-06T00:00:00","2009-11-07T00:00:00","2009-11-08T00:00:00","2009-11-09T00:00:00","2009-11-10T00:00:00","2009-11-11T00:00:00","2009-11-12T00:00:00","2009-11-13T00:00:00","2009-11-14T00:00:00","2009-11-15T00:00:00","2009-11-16T00:00:00","2009-11-17T00:00:00","2009-11-18T00:00:00","2009-11-19T00:00:00","2009-11-20T00:00:00","2009-11-21T00:00:00","2009-11-22T00:00:00","2009-11-23T00:00:00","2009-11-24T00:00:00","2009-11-25T00:00:00","2009-11-26T00:00:00","2009-11-27T00:00:00","2009-11-28T00:00:00","2009-11-29T00:00:00","2009-11-30T00:00:00","2009-12-01T00:00:00","2009-12-02T00:00:00","2009-12-03T00:00:00","2009-12-04T00:00:00","2009-12-05T00:00:00","2009-12-06T00:00:00","2009-12-07T00:00:00","2009-12-08T00:00:00","2009-12-09T00:00:00","2009-12-10T00:00:00","2009-12-11T00:00:00","2009-12-12T00:00:00","2009-12-13T00:00:00","2009-12-14T00:00:00","2009-12-15T00:00:00","2009-12-16T00:00:00","2009-12-17T00:00:00","2009-12-18T00:00:00","2009-12-19T00:00:00","2009-12-20T00:00:00","2009-12-21T00:00:00","2009-12-22T00:00:00","2009-12-23T00:00:00","2009-12-24T00:00:00","2009-12-25T00:00:00","2009-12-26T00:00:00","2009-12-27T00:00:00","2009-12-28T00:00:00","2009-12-29T00:00:00","2009-12-30T00:00:00","2009-12-31T00:00:00","2010-01-01T00:00:00 ...

# %%
# Try only TTF with coal_price

# %%
# Normalize the data

features = df_other_features[['TTF_Price', 'Coal_Price']]
scaler = MinMaxScaler()
scaled = scaler.fit_transform(features)

window_size = 90
horizon_days = 30
test_split=0.2

X, y = create_sequences_multifeature(scaled, window_size=window_size, horizon=horizon_days)
split = int(len(X) * (1 - test_split))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (4545, 90, 2)
# X_test shape: (1137, 90, 2)
# y_train shape: (4545,)
# y_test shape: (1137,)

# %%
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam

model_ttf_coal = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),  # Preferred input shape
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(64),
    Dense(1)
])

model_ttf_coal.compile(
    optimizer=Adam(),
    loss='mse',
    metrics=[
        MeanAbsoluteError(name='mae'),
        RootMeanSquaredError(name='rmse'),
        MeanAbsolutePercentageError(name='mape')
    ]
)

# Train model with EarlyStopping
history = model_ttf_coal.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[EarlyStopping(patience=5)],
    verbose=1
)
# Out:
# Epoch 1/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 3.3480e-04 - mae: 0.0130 - mape: 1526.7937 - rmse: 0.0173 - val_loss: 0.0075 - val_mae: 0.0542 - val_mape: 25.8006 - val_rmse: 0.0867
# Epoch 2/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.8126e-05 - mae: 0.0062 - mape: 3865.7126 - rmse: 0.0082 - val_loss: 0.0062 - val_mae: 0.0474 - val_mape: 21.8146 - val_rmse: 0.0788
# Epoch 3/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.4605e-05 - mae: 0.0061 - mape: 1106.1039 - rmse: 0.0080 - val_loss: 0.0069 - val_mae: 0.0503 - val_mape: 23.4984 - val_rmse: 0.0830
# Epoch 4/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.6901e-05 - mae: 0.0060 - mape: 5020.0249 - rmse: 0.0082 - val_loss: 0.0071 - val_mae: 0.0514 - val_mape: 24.1171 - val_rmse: 0.0841
# Epoch 5/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.2775e-05 - mae: 0.0061 - mape: 433.2006 - rmse: 0.0085 - val_loss: 0.0065 - val_mae: 0.0490 - val_mape: 22.9403 - val_rmse: 0.0809
# Epoch 6/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.5929e-05 - mae: 0.0059 - mape: 193.9595 - rmse: 0.0081 - val_loss: 0.0067 - val_mae: 0.0492 - val_mape: 22.8555 - val_rmse: 0.0818
# Epoch 7/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.6797e-05 - mae: 0.0058 - mape: 1004.9327 - rmse: 0.0082 - val_loss: 0.0071 - val_mae: 0.0512 - val_mape: 23.9373 - val_rmse: 0.0845

# %%
## Evaluate the model
y_pred = model_ttf_coal.predict(X_test).flatten()

# 2. Inverse scale both y_test and y_pred (only the TTF_Price column)
y_test_inv = scaler.inverse_transform(
    np.hstack([y_test.reshape(-1, 1), np.zeros((len(y_test), scaled.shape[1] - 1))])
)[:, 0]

y_pred_inv = scaler.inverse_transform(
    np.hstack([y_pred.reshape(-1, 1), np.zeros((len(y_pred), scaled.shape[1] - 1))])
)[:, 0]

forecast_metrics(y_test_inv, y_pred_inv)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# {'MAE': 16.821991654129082,
#  'MSE': 1143.2611863356399,
#  'RMSE': np.float64(33.81214554469503),
#  'R²': 0.5269713023921083}

# %% [markdown]
# Try to fine tune the LSTM hyper parameters

# %%
param_grid = {
    'window_sizes': [30, 90, 180],
    'dropouts': [0.2, 0.4, 0.5],
    'learning_rates': [0.001, 0.0001]
}


results = []

for window_size in param_grid['window_sizes']:
    for dropout in param_grid['dropouts']:
        for lr in param_grid['learning_rates']:

            # Prepare sequences
            X, y = create_sequences_multifeature(scaled, window_size=window_size, horizon=horizon_days)
            split = int(len(X) * (1 - test_split))
            X_train, X_test = X[:split], X[split:]
            y_train, y_test = y[:split], y[split:]

            # Build model
            model = Sequential([
                Input(shape=(X_train.shape[1], X_train.shape[2])),
                LSTM(64, return_sequences=True),
                Dropout(dropout),
                LSTM(64),
                Dense(1)
            ])
            model.compile(
                optimizer=Adam(learning_rate=lr),
                loss='mse',
                metrics=['mae']
            )

            # Train
            history = model.fit(
                X_train, y_train,
                epochs=50,
                batch_size=32,
                validation_split=0.1,
                callbacks=[EarlyStopping(patience=5)],
                verbose=0
            )

            # Predict
            y_pred = model.predict(X_test).flatten()

            # Inverse scale
            y_test_inv = scaler.inverse_transform(
                np.hstack([y_test.reshape(-1, 1), np.zeros((len(y_test), scaled.shape[1] - 1))])
            )[:, 0]

            y_pred_inv = scaler.inverse_transform(
                np.hstack([y_pred.reshape(-1, 1), np.zeros((len(y_pred), scaled.shape[1] - 1))])
            )[:, 0]

            # Metrics
            mae = mean_absolute_error(y_test_inv, y_pred_inv)
            rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
            r2 = r2_score(y_test_inv, y_pred_inv)

            results.append({
                'window_size': window_size,
                'dropout': dropout,
                'learning_rate': lr,
                'mae': mae,
                'rmse': rmse,
                'r2': r2
            })

            print(f"✅ Tested window={window_size}, dropout={dropout}, lr={lr} ➝ MAE={mae:.4f}, RMSE={rmse:.4f}, r2 = {r2}")
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ✅ Tested window=30, dropout=0.2, lr=0.001 ➝ MAE=16.4730, RMSE=33.1861, r2 = 0.5420156559940155
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ✅ Tested window=30, dropout=0.2, lr=0.0001 ➝ MAE=17.7135, RMSE=35.0804, r2 = 0.48823867542710186
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ✅ Tested window=30, dropout=0.4, lr=0.001 ➝ MAE=16.4826, RMSE=32.8751, r2 = 0.5505579911517133
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# ✅ Tested window=30, dropout=0.4, lr=0.0001 ➝ MAE=18.1537, RMSE=35.0205, r2 = 0.4899843277511956
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# ✅ Tested window=30, dropout=0.5, lr=0.001 ➝ MAE=17.4415, RMSE=35.1105, r2 = 0.4873605648624839
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ✅ Tested window=30, dropout=0.5, lr=0.0001 ➝ MAE=17.4017, RMSE=34.4293, r2 = 0.5070582790967095
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ✅ Tested window=90, dropout=0.2, lr=0.001 ➝ MAE=16.9924, RMSE=33.4569, r2 = 0.5368582209791319
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ✅ Tested window=90, dropout=0.2, lr=0.0001 ➝ MAE=17.9860, RMSE=34.8834, r2 = 0.4965220530464872
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# ✅ Tested window=90, dropout=0.4, lr=0.001 ➝ MAE=16.8835, RMSE=34.0955, r2 = 0.5190106588121475
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ✅ Tested window=90, dropout=0.4, lr=0.0001 ➝ MAE=17.8957, RMSE=34.8910, r2 = 0.49630322900561585
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# ✅ Tested window=90, dropout=0.5, lr=0.001 ➝ MAE=17.0660, RMSE=34.7607, r2 = 0.5000599069899163
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ✅ Tested window=90, dropout=0.5, lr=0.0001 ➝ MAE=17.8205, RMSE=34.4936, r2 = 0.5077129140103942
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# ✅ Tested window=180, dropout=0.2, lr=0.001 ➝ MAE=17.5165, RMSE=35.2312, r2 = 0.4918278443516272
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# ✅ Tested window=180, dropout=0.2, lr=0.0001 ➝ MAE=18.5218, RMSE=36.3920, r2 = 0.4577904003524761
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ✅ Tested window=180, dropout=0.4, lr=0.001 ➝ MAE=16.9880, RMSE=33.3357, r2 = 0.5450392947771243
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ✅ Tested window=180, dropout=0.4, lr=0.0001 ➝ MAE=18.0007, RMSE=34.8691, r2 = 0.5022207844889213
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ✅ Tested window=180, dropout=0.5, lr=0.001 ➝ MAE=16.8176, RMSE=33.6227, r2 = 0.5371721970296337
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ✅ Tested window=180, dropout=0.5, lr=0.0001 ➝ MAE=18.1656, RMSE=34.9601, r2 = 0.49961804597340576
